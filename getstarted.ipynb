# %% [markdown]
# ### Quickstart: Compare runs, choose a model, and deploy it to a REST API
#
# In this quickstart, you will:
# - Run a hyperparameter sweep on a training script
# - Compare the results of the runs in the MLflow UI
# - Choose the best run and register it as a model
# - Deploy the model to a REST API
# - Build a container image suitable for deployment to a cloud platform

# %%
import keras 
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import mlflow
from mlflow.models import infer_signature

# %%
### Load the dataset
data  = pd.read_csv("https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv", sep=';')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
### Split the data into training, testing, and validation sets
train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
train_x = train.drop(columns=['quality']).values
train_y = train[['quality']].values.ravel()

test_x = test.drop(columns=['quality']).values
test_y = test[['quality']].values.ravel()

train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.2, random_state=42)

signature = infer_signature(train_x, train_y)

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective (params) :
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3, 
        train_x=train_x, 
        train_y=train_y, 
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space = {
    "lr":hp.loguniform("lr", np.log(1e-5), np.log(1e-1)), 
    "momentum": hp.uniform("momentum", 0.0, 1.0)
}

# %%
mlflow.set_experiment("/wine-quality")
with mlflow.start_run():
    # conduct the hyperparameter search using hyperopt
    trials = Trials()
    best =fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials,
    )

    # fetch the best details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    ## Log the best parameters, loss and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print the best parameters
    print("Best parameters: ", best)
    print("Best eval rmse: ", best_run["loss"])
# Out:
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 13s 310ms/step - loss: 33.1318 - root_mean_squared_error: 5.7560
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.4795 - root_mean_squared_error: 5.7861 - val_loss: 32.8789 - val_root_mean_squared_error: 5.7340
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 31.0397 - root_mean_squared_error: 5.5713
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.5802 - root_mean_squared_error: 5.7078 - val_loss: 32.1264 - val_root_mean_squared_error: 5.6680
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32.7988 - root_mean_squared_error: 5.7270
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.2372 - root_mean_squared_error: 5.6777 - val_loss: 31.3918 - val_root_mean_squared_error: 5.6028
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.3804 - root_mean_squared_error: 5.6018
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.1044 - root_mean_squared_error: 5.5771
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - loss: 34.8708 - root_mean_squared_error: 5.9052
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.1607 - root_mean_squared_error: 3.6192 - val_loss: 1.5149 - val_root_mean_squared_error: 1.2308
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5053 - root_mean_squared_error: 1.2269
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4031 - root_mean_squared_error: 1.1833 - val_loss: 1.1098 - val_root_mean_squared_error: 1.0535
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0313 - root_mean_squared_error: 1.0155
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0675 - root_mean_squared_error: 1.0324 - val_loss: 0.9279 - val_root_mean_squared_error: 0.9633
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8794 - root_mean_squared_error: 0.9378
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9426 - root_mean_squared_error: 0.9706
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 10s 225ms/step - loss: 38.8176 - root_mean_squared_error: 6.2304
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1869 - root_mean_squared_error: 2.8421 - val_loss: 0.7722 - val_root_mean_squared_error: 0.8787
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5285 - root_mean_squared_error: 0.7270
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6403 - root_mean_squared_error: 0.8000 - val_loss: 0.6111 - val_root_mean_squared_error: 0.7817
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6057 - root_mean_squared_error: 0.7783
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6129 - root_mean_squared_error: 0.7827 - val_loss: 0.5473 - val_root_mean_squared_error: 0.7398
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5075 - root_mean_squared_error: 0.7124
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5315 - root_mean_squared_error: 0.7288
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - loss: 36.9531 - root_mean_squared_error: 6.0789
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.6976 - root_mean_squared_error: 5.7177 - val_loss: 30.7369 - val_root_mean_squared_error: 5.5441
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 28.7918 - root_mean_squared_error: 5.3658
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29.7792 - root_mean_squared_error: 5.4569 - val_loss: 28.3036 - val_root_mean_squared_error: 5.3201
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.0615 - root_mean_squared_error: 5.4828
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27.6083 - root_mean_squared_error: 5.2541 - val_loss: 26.0669 - val_root_mean_squared_error: 5.1056
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.0558 - root_mean_squared_error: 5.1045
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.8399 - root_mean_squared_error: 5.0833
#
# 100%|██████████| 4/4 [00:34<00:00,  8.53s/trial, best loss: 0.7397831082344055]
# Best parameters:  {'lr': np.float64(0.018473144456171223), 'momentum': np.float64(0.7292729862171791)}
# Best eval rmse:  0.7397831082344055

# %%
# Inferencing 
from mlflow.models import validate_serving_input

model_uri = 'runs:/08fd29b0cdd641218db95ecc7d17f58e/model'

# The logged model does not contain an input_example.
# Manually generate a serving payload to verify your model prior to deployment.
from mlflow.models import convert_input_example_to_serving_input
# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)
# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# Downloading artifacts: 100%|██████████| 7/7 [00:00<00:00, 3398.16it/s]
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# array([[6.258827 ],
#        [6.801276 ],
#        [6.4341345],
#        ...,
#        [6.3881445],
#        [6.733959 ],
#        [5.6480894]], dtype=float32)
